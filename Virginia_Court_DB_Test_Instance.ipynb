# %%
import numpy as np
import pandas as pd
import datetime
import os
import pathlib
import shutil
import webbrowser
import time
import pathlib
import math
import sklearn
from sklearn.preprocessing import LabelEncoder

import sqlite3
from sqlite3 import Error
import sqlalchemy
from sqlalchemy import create_engine

# Import data visualization libraries
import altair as alt
import seaborn as sns
import matplotlib.pyplot as plt
#import xlsxwriter

# %matplotlib inline
#sns.set(style='ticks')

# Allow code cells to display multiple items in the output instead of the last item at the bottom of the cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# Expand the number of rows and columns displayed in the notebook outputs
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('max_colwidth', 50)
pd.set_option('memory_usage',True)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#%cd '/content/drive/MyDrive/Development/Project Folders/Virginia_Court_Data_Analysis/'
# %pwd

# %%
project_folder_path = '/content/drive/MyDrive/Development/Project Folders/Virginia_Court_Data_Analysis/'
DB_NAME = 'Virginia_Court_DB.db'
DB_PATH = os.path.join(project_folder_path,DB_NAME)

conn = sqlite3.connect(DB_PATH)
c = conn.cursor()
engine = create_engine(f"sqlite:////{DB_PATH}")
#engine = create_engine(f"sqlite:////{pwd}/{DB_NAME}")

# %%
dfa_df = pd.read_sql('SELECT * FROM Cases_By_Defendant',con=conn)

# %%
dfa_df
# Out:
#          index      person_id  fips   FiledDate Commencedby             Locality                    Status DefenseAttorney                 Address  Gender                                     Race                          Charge    CodeSection     CaseType Class OffenseDate  ArrestDate        Complainant                  AmendedCharge AmendedCodeSection AmendedCaseType    FinalDisposition DispositionDate JailPenitentiary ConcurrentConsecutive LifeDeath  SentenceTime  SentenceSuspendedTime ProbationType  ProbationTime ProbationStarts  OperatorLicenseSuspensionTime RestrictionEffectiveDate RestrictionEndDate OperatorLicenseRestrictionCodes DrivingRestrictions   Fine  Costs FineCostsDue FineCostsPaid FineCostsPaidDate VASAP FineCostsPastDue CourtDMVSurrender DriverImprovementClinic RestitutionPaid  RestitutionAmount Military TrafficFatality AppealedDate
# ...
